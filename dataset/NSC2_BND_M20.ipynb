# %%
import pymongo as mg
import pandas as pd

# %%
client = mg.MongoClient(host='mongodb://localhost:27017')

# %%
database = client['db_NHIS']

# %%
collection = database['Join Collection NSC2_BND_M20']

# %%
cursor = collection.find({"SICK_SYM1":"I10"})

# %%
list_patient = list(cursor)
list_patient
# Out:
# [{'_id': ObjectId('64e6c524f22b93c7fc16a1e6'),
#   'RN_INDI': 646257,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 200805,
#   'COD1': 'A15-A19',
#   'RN_KEY': 2002070306096,
#   'RN_INST': 57097,
#   'MDCARE_STRT_DT': 20020710,
#   'FORM_CD': 3,
#   'MCARE_SUBJ_CD': 1,
#   'SICK_SYM1': 'I10',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 1,
#   'VSHSP_DD_CNT': 1,
#   'TOT_PRSC_DD_CNT': 30,
#   'MCARE_RSLT_TYPE': 5,
#   'EDC_ADD_RT': 0.15,
#   'ED_RC_TOT_AMT': 7570,
#   'EDC_SBA': 3000,
#   'EDC_INSUR_BRDN_AMT': 4570,
#   'STD_YYYY': 2002},
#  {'_id': ObjectId('64e6c524f22b93c7fc16a1eb'),
#   'RN_INDI': 646257,
#   'BTH_YYYY': '1921LE',
#   'DTH_YYYYMM': 200805,
#   'COD1': 'A15-A19',
#   'RN_KEY': 2002080588993,
#   'RN_INST': 57097,
#   'MDCARE_STRT_DT': 20020805,
#   'FORM_CD': 3,
#   'MCARE_SUBJ_CD': 1,
#   'SICK_SYM1': 'I10',
#   'OFIJ_TYPE': 0,
#   'OPRTN_YN': 0,
#   'MDCARE_DD_CNT': 2,
#   'VSHSP_DD_CNT': 2,
#   'TOT_PRSC_DD_CNT': 60,
#   'MCARE_RSLT_TYPE': 5,
# ...

# %%
df_NBM = pd.DataFrame(list_patient)

# %%
df_NBM
# Out:
#                            _id  RN_INDI BTH_YYYY  DTH_YYYYMM     COD1  \
# 0     64e6c524f22b93c7fc16a1e6   646257   1921LE    200805.0  A15-A19
# 1     64e6c524f22b93c7fc16a1eb   646257   1921LE    200805.0  A15-A19
# 2     64e6c524f22b93c7fc16a1ed   646257   1921LE    200805.0  A15-A19
# 3     64e6c524f22b93c7fc16a244   646257   1921LE    200805.0  A15-A19
# 4     64e6c524f22b93c7fc16a429   966199   1921LE    201409.0      J69
# ...                        ...      ...      ...         ...      ...
# 4624  64e6c545f22b93c7fc18877f   314882     2005         NaN      NaN
# 4625  64e6c545f22b93c7fc188780   314882     2005         NaN      NaN
# 4626  64e6c545f22b93c7fc188781   314882     2005         NaN      NaN
# 4627  64e6c545f22b93c7fc18878a   314882     2005         NaN      NaN
# 4628  64e6c545f22b93c7fc1887e9   314882     2005         NaN      NaN
#
#              RN_KEY  RN_INST  MDCARE_STRT_DT  FORM_CD  MCARE_SUBJ_CD  ...  \
# ...

# %%
df_NBM = df_NBM[['OFIJ_TYPE','OPRTN_YN','MDCARE_DD_CNT','VSHSP_DD_CNT','TOT_PRSC_DD_CNT','ED_RC_TOT_AMT']]
df_NBM
# Out:
#      OFIJ_TYPE  OPRTN_YN  MDCARE_DD_CNT  VSHSP_DD_CNT  TOT_PRSC_DD_CNT  \
# 0            0         0              1             1               30
# 1            0         0              2             2               60
# 2            0         0              1             1               30
# 3            0         0              1             1                7
# 4            0         0              1             1                7
# ...        ...       ...            ...           ...              ...
# 4624         0         0              1             1               30
# 4625         0         0              1             1               30
# 4626         0         0              1             1               30
# 4627         0         0              1             1               30
# 4628         0         0              1             1               30
#
#       ED_RC_TOT_AMT
# 0              7570
# 1             18160
# 2              7570
# 3             14200
# ...

# %%
df_NBM.to_csv('./df_NBM.csv')
